# %%
import pandas as pd

test_df = pd.read_csv("C:/Users/ozlem/OneDrive/Masaüstü/dataset/Titanic_test.csv")
test_df.head()
#print(test_df.head())
train_df = pd.read_csv("C:/Users/ozlem/OneDrive/Masaüstü/dataset/Titanic_train.csv")

frames = [test_df, train_df]
merging_sets = pd.concat(frames)

#print(merging_sets)
#print(list(merging_sets.columns))
merging_sets.head(8)
#merging_sets.head(8).describe()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 5          897       3                    Svensson, Mr. Johan Cervin    male
# 6          898       3                          Connolly, Miss. Kate  female
# 7          899       2                  Caldwell, Mr. Albert Francis    male
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Survived
# 0  34.5      0      0   330911   7.8292   NaN        Q       NaN
# 1  47.0      1      0   363272   7.0000   NaN        S       NaN
# 2  62.0      0      0   240276   9.6875   NaN        Q       NaN
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

grouped_data = merging_sets.groupby(["Sex", "Survived"])

for name, group in grouped_data:
    plt.hist(group['Sex'], label=name)
    plt.legend()
plt.xlabel('Sex')
plt.ylabel('Survived')


plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

test_df = pd.read_csv("C:/Users/ozlem/OneDrive/Masaüstü/dataset/Titanic_test.csv")
test_df.head()
#print(test_df.head())
train_df = pd.read_csv("C:/Users/ozlem/OneDrive/Masaüstü/dataset/Titanic_train.csv")

frames = [test_df, train_df]
merging_sets = pd.concat(frames)

#print(merging_sets)
#print(list(merging_sets.columns))
merging_sets.head(8)
#merging_sets.head(8).describe()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 5          897       3                    Svensson, Mr. Johan Cervin    male
# 6          898       3                          Connolly, Miss. Kate  female
# 7          899       2                  Caldwell, Mr. Albert Francis    male
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Survived
# 0  34.5      0      0   330911   7.8292   NaN        Q       NaN
# 1  47.0      1      0   363272   7.0000   NaN        S       NaN
# 2  62.0      0      0   240276   9.6875   NaN        Q       NaN
# ...

# %%
grouped_data = merging_sets.groupby(["Pclass", "Survived"])

for name, group in grouped_data:
    plt.hist(group['Pclass'], label=name)
    plt.legend()
plt.xlabel('Pclass')
plt.ylabel('Survived')


plt.show()

# %%
del merging_sets['PassengerId']
merging_sets.drop('Cabin', axis=1, inplace=True)

# %%
merging_sets.head()
# Out:
#    Pclass                                          Name     Sex   Age  SibSp  \
# 0       3                              Kelly, Mr. James    male  34.5      0
# 1       3              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2       2                     Myles, Mr. Thomas Francis    male  62.0      0
# 3       3                              Wirz, Mr. Albert    male  27.0      0
# 4       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
#
#    Parch   Ticket     Fare Embarked  Survived
# 0      0   330911   7.8292        Q       NaN
# 1      0   363272   7.0000        S       NaN
# 2      0   240276   9.6875        Q       NaN
# 3      0   315154   8.6625        S       NaN
# 4      1  3101298  12.2875        S       NaN

# %%
merging_sets['Sex'] = merging_sets['Sex'].replace({'male' : 0})
merging_sets['Sex'] = merging_sets['Sex'].replace({'female' : 1})
merging_sets.head()
# Out:
#    Pclass  Sex   Age  SibSp  Parch   Ticket     Fare Embarked  Survived
# 0       3    0  34.5      0      0   330911   7.8292        Q       NaN
# 1       3    1  47.0      1      0   363272   7.0000        S       NaN
# 2       2    0  62.0      0      0   240276   9.6875        Q       NaN
# 3       3    0  27.0      0      0   315154   8.6625        S       NaN
# 4       3    1  22.0      1      1  3101298  12.2875        S       NaN

# %%
merging_sets.head()
#merging_sets.drop('Name', axis = 1, inplace=True)
# Out:
#    Pclass     Sex   Age  SibSp  Parch   Ticket     Fare Embarked  Survived
# 0       3    male  34.5      0      0   330911   7.8292        Q       NaN
# 1       3  female  47.0      1      0   363272   7.0000        S       NaN
# 2       2    male  62.0      0      0   240276   9.6875        Q       NaN
# 3       3    male  27.0      0      0   315154   8.6625        S       NaN
# 4       3  female  22.0      1      1  3101298  12.2875        S       NaN

# %%
import seaborn as sns

trying = sns.load_dataset("merging_sets").pivot("Sex", "Age", "Ticket")
sns.heatmap(trying)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 import seaborn as sns
#       3 trying = sns.load_dataset("merging_sets").pivot("Sex", "Age", "Ticket")
#       4 sns.heatmap(trying)
#
# ModuleNotFoundError: No module named 'seaborn'
